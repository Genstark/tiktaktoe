# %% [markdown]
# # Analytics / Computing with Python Assignment
# Name: Rahul Yadav
# Class: _______
# Roll No: _______

# %% [markdown]
# ## Q1: Python Data Types

# %%
a = 10
b = 3.14
c = 'Rahul'
d = True
e = [1,2,3]
f = (4,5,6)
g = {'name':'Rahul','age':20}

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))

# %% [markdown]
# ## Q2: Personal Details

# %%
name='Rahul'
age=20
city='Delhi'
cgpa=8.5

print(f'My name is {name}, I am {age} years old, from {city}, with CGPA {cgpa}')

# %% [markdown]
# ## Q3: Conditions

# %%
num=int(input('Enter number: '))

if num>0:
    print('Positive')
elif num<0:
    print('Negative')
else:
    print('Zero')

if num%2==0:
    print('Even')
else:
    print('Odd')

# %% [markdown]
# ## Q4: Loops

# %%
# Multiplication Table
n=int(input('Enter number: '))
for i in range(1,11):
    print(n,'x',i,'=',n*i)

# Sum 1 to 100
i=1
total=0
while i<=100:
    total+=i
    i+=1
print('Sum=',total)

# %% [markdown]
# ## Q5: Function Calculator

# %%
def calculator(a,b,operation):
    if operation=='add':
        return a+b
    elif operation=='subtract':
        return a-b
    elif operation=='multiply':
        return a*b
    elif operation=='divide':
        if b==0:
            return 'Cannot divide by zero'
        return a/b
    else:
        return 'Invalid operation'

print(calculator(10,5,'add'))

# %% [markdown]
# ## Q6: NumPy

# %%
import numpy as np
arr=np.random.randint(1,50,10)
print(arr)

print('Shape:',arr.shape)
print('Size:',arr.size)
print('Mean:',np.mean(arr))
print('Median:',np.median(arr))
print('Std:',np.std(arr))
print('Slice:',arr[2:8])
print('Reshape:\n',arr.reshape(2,5))

# %% [markdown]
# ## Q7: Matplotlib

# %%
import matplotlib.pyplot as plt
months=['Jan','Feb','Mar','Apr','May','Jun']
sales=[200,250,300,280,350,400]

plt.plot(months,sales)
plt.title('Sales Trend')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.show()

plt.bar(months,sales)
plt.title('Sales Comparison')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ## Q8: Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset('iris')

sns.histplot(data['sepal_length'])
plt.show()

sns.scatterplot(x='sepal_length',y='sepal_width',data=data)
plt.show()

corr=data.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
plt.show()
